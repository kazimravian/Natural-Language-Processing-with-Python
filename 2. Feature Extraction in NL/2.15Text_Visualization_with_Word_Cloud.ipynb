# %% [markdown]
# <h1><b><font size = '7'>
# Text Visualization with Cloud Method
# </font></b></h1>

# %% [markdown]
# <b>In this activity, you will create a word cloud for the 50 most frequent words in a dataset. <br>
# The dataset we will use consists of random sentences that are not clean.<br>
# First, we need to clean them and create a unique set of frequently occurring words.</b>

# %% [markdown]
# **1. Open a Jupyter Notebook. Insert a new cell and add the following code to import the necessary libraries:**

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('punkt') # This line downloads the Punkt tokenizer models for NLTK.
nltk.download('omw-1.4') # This line downloads the Open Multilingual Wordnet (OMW) database for NLTK.
from collections import Counter
import re
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %% [markdown]
# **2. To fetch the dataset and read its content, add the following code:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
text = open('/content/drive/MyDrive/NLP/2. Feature Extraction Methods in NLP/text_corpus.txt', 'r', encoding='utf-8').read()

# %% [markdown]
# **3. The text in the fetched data is not clean. In order to clean it, we need to make use of various preprocessing steps, such as tokenization and lemmatization.**

# %%
# this user defined function apply the tokenization and lemmatization process for cleaning text
def lemmatize_and_clean(text):

  # this line of code downloads the WordNet corpus, which is a lexical database for the English language.
  nltk.download('wordnet')
  # creatte the object of WordNetLemmatizer class
  lemmatizer = WordNetLemmatizer()
  # clean the texy
  cleaned_lemmatized_tokens = [lemmatizer.lemmatize(word.lower()) for word in word_tokenize (re.sub(r'([^\s\w]|_)+', ' ', text))]

  return cleaned_lemmatized_tokens

# %% [markdown]
# **4. To check the set of unique words, along with their frequencies, as well as to find the 50 most frequently occurring words, add the following code:**

# %%
# this line of code shows the 50 most frequent words
Counter(lemmatize_and_clean(text)).most_common(50)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [('the', 31),
#  ('to', 12),
#  ('and', 8),
#  ('of', 8),
#  ('field', 7),
#  ('on', 6),
#  ('new', 5),
#  ('zealand', 5),
#  ('in', 5),
#  ('with', 5),
#  ('mckenzie', 4),
#  ('wa', 4),
#  ('wicket', 4),
#  ('by', 4),
#  ('s', 4),
#  ('clarke', 4),
#  ('joey', 3),
#  ('after', 3),
#  ('west', 3),
#  ('indie', 3),
#  ('their', 3),
#  ('final', 3),
#  ('at', 3),
#  ('spiritofcricket', 3),
#  ('it', 3),
#  ('2', 3),
#  ('unbeaten', 3),
#  ('player', 2),
#  ('off', 2),
#  ('u', 2),
#  ('19', 2),
#  ('world', 2),
#  ('cup', 2),
#  ('his', 2),
#  ('99', 2),
#  ('face', 2),
#  ('back', 2),
#  ('ball', 2),
#  ('kiwi', 2),
#  ('who', 2),
#  ('while', 2),
#  ('being', 2),
#  ('applauded', 2),
#  ('south', 2),
#  ('africa', 2),
#  ('rohit', 2),
#  ('also', 2),
#  ('so', 2),
#  ('good', 2),
#  ('see', 2)]

# %% [markdown]
# **5. Once you get the set of unique words along with their frequencies, remove the stop words. Then, generate the word cloud for the top 50 most frequent words. Add the following code to implement this:**

# %%
stopwords = set(STOPWORDS)
cleaned_text = ' '.join(lemmatize_and_clean(text))
wordcloud = WordCloud(width = 800, height = 800,
                      background_color ='white',
                      max_words=50,
                      stopwords = stopwords,
                      min_font_size = 10).generate(cleaned_text)

plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
